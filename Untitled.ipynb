# %%
import numpy as np

import sqlalchemy
from sqlalchemy import inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = sqlalchemy.create_engine("postgresql://postgres:postgres@localhost:5432/launch_db")
connection = engine.connect()
metadata = sqlalchemy.MetaData()
launch_data = sqlalchemy.Table("launch_data", metadata, autoload=True, autoload_with=engine)

# %%
session = Session(engine)

"""Return a list of all launch data"""
# Query all passengers
results = session.query(launch_data).all()
print(type(results))
# Out:
# <class 'list'>

# %%
Inspector = inspect(engine)
Inspector.get_table_names()
columns = Inspector.get_columns('launch_data')
# print(columns)
launch_data_column_names = []
for column in columns:
    launch_data_column_names.append(column['name'])
print(launch_data_column_names)
# Out:
# ['flight_number', 'launch_year', 'launch_date_utc', 'launch_success', 'Site_ID', 'Site_Name', 'Nationality', 'Payload_type', 'Rocket_Name']

# %%
return_data = []
for result in results:
    current_dict = {}
    for index, column_name in enumerate(launch_data_column_names):
        current_dict[column_name] = result[index]
    return_data.append(current_dict)

# %%
return_data
# Out:
# [{'flight_number': 1,
#   'launch_year': '2006',
#   'launch_date_utc': datetime.date(2006, 3, 24),
#   'launch_success': False,
#   'Site_ID': 'kwajalein_atoll',
#   'Site_Name': 'Kwajalein Atoll',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 1'},
#  {'flight_number': 2,
#   'launch_year': '2007',
#   'launch_date_utc': datetime.date(2007, 3, 21),
#   'launch_success': False,
#   'Site_ID': 'kwajalein_atoll',
#   'Site_Name': 'Kwajalein Atoll',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 1'},
#  {'flight_number': 3,
#   'launch_year': '2008',
#   'launch_date_utc': datetime.date(2008, 8, 3),
#   'launch_success': False,
#   'Site_ID': 'kwajalein_atoll',
#   'Site_Name': 'Kwajalein Atoll',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 1'},
#  {'flight_number': 4,
#   'launch_year': '2008',
#   'launch_date_utc': datetime.date(2008, 9, 28),
#   'launch_success': True,
#   'Site_ID': 'kwajalein_atoll',
#   'Site_Name': 'Kwajalein Atoll',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 1'},
#  {'flight_number': 5,
#   'launch_year': '2009',
#   'launch_date_utc': datetime.date(2009, 7, 13),
#   'launch_success': True,
#   'Site_ID': 'kwajalein_atoll',
#   'Site_Name': 'Kwajalein Atoll',
#   'Nationality': 'Malaysia',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 1'},
#  {'flight_number': 6,
#   'launch_year': '2010',
#   'launch_date_utc': datetime.date(2010, 6, 4),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon Boilerplate',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 7,
#   'launch_year': '2010',
#   'launch_date_utc': datetime.date(2010, 12, 8),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.0',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 8,
#   'launch_year': '2012',
#   'launch_date_utc': datetime.date(2012, 5, 22),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.0',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 9,
#   'launch_year': '2012',
#   'launch_date_utc': datetime.date(2012, 10, 8),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.0',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 10,
#   'launch_year': '2013',
#   'launch_date_utc': datetime.date(2013, 3, 1),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.0',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 11,
#   'launch_year': '2013',
#   'launch_date_utc': datetime.date(2013, 9, 29),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'Canada',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 12,
#   'launch_year': '2013',
#   'launch_date_utc': datetime.date(2013, 12, 3),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Luxembourg',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 13,
#   'launch_year': '2014',
#   'launch_date_utc': datetime.date(2014, 1, 6),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Thailand',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 14,
#   'launch_year': '2014',
#   'launch_date_utc': datetime.date(2014, 4, 18),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 15,
#   'launch_year': '2014',
#   'launch_date_utc': datetime.date(2014, 7, 14),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 16,
#   'launch_year': '2014',
#   'launch_date_utc': datetime.date(2014, 8, 5),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Hong Kong',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 17,
#   'launch_year': '2014',
#   'launch_date_utc': datetime.date(2014, 9, 7),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Hong Kong',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 18,
#   'launch_year': '2014',
#   'launch_date_utc': datetime.date(2014, 9, 21),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 19,
#   'launch_year': '2015',
#   'launch_date_utc': datetime.date(2015, 1, 10),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 20,
#   'launch_year': '2015',
#   'launch_date_utc': datetime.date(2015, 2, 11),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 21,
#   'launch_year': '2015',
#   'launch_date_utc': datetime.date(2015, 3, 2),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Hong Kong',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 22,
#   'launch_year': '2015',
#   'launch_date_utc': datetime.date(2015, 4, 14),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 23,
#   'launch_year': '2015',
#   'launch_date_utc': datetime.date(2015, 4, 27),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Turkmenistan',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 24,
#   'launch_year': '2015',
#   'launch_date_utc': datetime.date(2015, 6, 28),
#   'launch_success': False,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 25,
#   'launch_year': '2015',
#   'launch_date_utc': datetime.date(2015, 12, 22),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 26,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 1, 17),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 27,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 3, 4),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Luxembourg',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 28,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 4, 8),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 29,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 5, 6),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Japan',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 30,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 5, 27),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Thailand',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 31,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 6, 15),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Hong Kong',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 32,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 7, 18),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 33,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 8, 14),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Japan',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 34,
#   'launch_year': '2016',
#   'launch_date_utc': datetime.date(2016, 9, 1),
#   'launch_success': False,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Israel',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 35,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 1, 14),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 36,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 2, 19),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 37,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 3, 16),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 38,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 3, 30),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'Luxembourg',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 39,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 5, 1),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 40,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 5, 15),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United Kingdom',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 41,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 6, 3),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 42,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 6, 23),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'Bulgaria',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 43,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 6, 25),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 44,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 7, 5),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 45,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 8, 14),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 46,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 8, 24),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'Taiwan',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 47,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 9, 7),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 48,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 10, 9),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 49,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 10, 11),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 50,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 10, 30),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'South Korea',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 51,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 12, 15),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 52,
#   'launch_year': '2017',
#   'launch_date_utc': datetime.date(2017, 12, 23),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 53,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 1, 8),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 54,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 1, 31),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Luxembourg',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 55,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 2, 6),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon Heavy'},
#  {'flight_number': 56,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 2, 22),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'Spain',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 57,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 3, 6),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Spain',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 58,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 3, 30),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 59,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 4, 2),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 60,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 4, 18),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 61,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 5, 11),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'Bangladesh',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 62,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 5, 22),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 63,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 6, 4),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Luxembourg',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 64,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 6, 29),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 65,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 7, 22),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Canada',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 66,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 7, 25),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 67,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 8, 7),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Indonesia',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 68,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 9, 10),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Canada',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 69,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 10, 8),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'Argentina',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 70,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 11, 15),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'Qatar',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 71,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 12, 3),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 72,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 12, 5),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 73,
#   'launch_year': '2018',
#   'launch_date_utc': datetime.date(2018, 12, 23),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 74,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 1, 11),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 75,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 2, 22),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Indonesia',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 76,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 3, 2),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Crew Dragon',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 77,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 4, 11),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'Saudi Arabia',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon Heavy'},
#  {'flight_number': 78,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 5, 4),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 79,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 5, 24),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 80,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 6, 12),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'Canada',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 81,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 6, 25),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon Heavy'},
#  {'flight_number': 82,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 7, 25),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 83,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 8, 6),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Israel',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 84,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 11, 11),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 85,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 12, 5),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 86,
#   'launch_year': '2019',
#   'launch_date_utc': datetime.date(2019, 12, 17),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Japan',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 87,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 1, 7),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 88,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 1, 19),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Crew Dragon',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 89,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 1, 29),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 90,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 2, 17),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 91,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 3, 7),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 1.1',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 92,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 3, 18),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 93,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 4, 22),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 94,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 5, 30),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Crew Dragon',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 95,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 6, 4),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 96,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 6, 13),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 97,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 6, 30),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 98,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 7, 20),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'South Korea',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 99,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 8, 7),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 100,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 8, 18),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 101,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 8, 30),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'Argentina',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 102,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 9, 3),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 103,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 10, 6),
#   'launch_success': None,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 104,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 10, 18),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 105,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 10, 24),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 106,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 11, 5),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 107,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 11, 16),
#   'launch_success': True,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Crew Dragon',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 108,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 11, 21),
#   'launch_success': True,
#   'Site_ID': 'vafb_slc_4e',
#   'Site_Name': 'VAFB SLC 4E',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 109,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 10, 24),
#   'launch_success': True,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 110,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 12, 6),
#   'launch_success': None,
#   'Site_ID': 'ksc_lc_39a',
#   'Site_Name': 'KSC LC 39A',
#   'Nationality': 'United States',
#   'Payload_type': 'Dragon 2.0',
#   'Rocket_Name': 'Falcon 9'},
#  {'flight_number': 111,
#   'launch_year': '2020',
#   'launch_date_utc': datetime.date(2020, 12, 13),
#   'launch_success': None,
#   'Site_ID': 'ccafs_slc_40',
#   'Site_Name': 'CCAFS SLC 40',
#   'Nationality': 'United States',
#   'Payload_type': 'Satellite',
#   'Rocket_Name': 'Falcon 9'}]
